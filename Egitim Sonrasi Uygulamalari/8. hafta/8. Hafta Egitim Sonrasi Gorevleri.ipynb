# %% [markdown]
# # Problem 1
#
# Şimdi beraber kullanıcılardan aldığımız verileri işleyerek, onlara hem çıktı verecek, hem de aldığımız ve hesapladığımız verileri ileride kullanabilmek adına kaydedeceğiz.
#
#
#  **Bu bir veri giriş platformu olacak**
#
#
#  * kullanıcıya kaç giriş yapacağını soracağız
# * kullanıcıdan isim-soyisim, yaş, boy, kilo bilgilerini alarak VKİ hesaplayacağız
# * ardından bunları sınıflara göre kaydedeceğiz bir dosyaya kaydedeceğiz
#
#
# Sınıflar ise şu şekilde:
# * 18, 5 kg/m.'nin altında olanlar: Zayıf
# * 18.5 – 24, 9 kg/m. arasında olanlar: Normal kilolu
# * 25 – 29, 9 kg/m. arasında olanlar: Fazla kilolu
# * 30 – 39, 9 kg/m. arasında olanlar: Obez
# * 40 kg/m.'nin üzerinde olanlar: İleri derecede obez (morbid obez), olarak görülür.

# %%
# 1.Problemin Çözümünü Buraya Yazınız
giris = int(input("Kaç giriş yapılacak: "))
for i in range(giris):
    isim = input("İsim: ")
    soyisim = input("Soyisim: ")
    yas = int(input("Yaş: "))
    boy = float(input("Boy(m): "))
    kilo = float(input("Kilo(kg): "))
    vki = kilo/(boy**2)
    sinif = ""
    if vki < 18.5:
        sinif = "Zayıf"
    elif 18.5 <= vki < 25:
        sinif = "Normal Kilolu"
    elif 25 <= vki < 30:
        sinif = "Fazla Kilolu"
    elif 30 <= vki < 40:
        sinif = "Obez"
    elif 40 <= vki:
        sinif = "Morbid Obez"
    with open("KullaniciVerileri.txt" , "a" , encoding="utf-8") as f:
        f.write("İsim: "+isim+"\n")
        f.write("Soyisim: "+soyisim+"\n")
        f.write("Vki: "+str(vki)+"\n")
        f.write("Sınıf: "+sinif+"\n")
        f.write("----------\n")

# %% [markdown]
# # Problem 2
# **YetBar - Smoothie Bank**
# ---
# YetBar spor salonunun girişinde bulunan, insansız bir sağlıklı içecek otomatıdır. Kullanıcı çeşitli girdiler smoothie içeceğine koyacağı ürünleri belirleyebilir, fiyat hesaplaması yaptırabilir ya da sadece menüyü görüntüleyebilir.
#
# **Projenin Amacı:**
#
# *   Birbirini etkileyen ve bir kod içerisinde birden fazla defa başvurulacak fonksiyonların oluşturulup, "fonksiyonel" proglamlamak.
# *   Büyük programları yazarken, yazılımcı olarak yapabileceğimiz hatalardan kaçınmak için kontrol yöntemleri geliştirmek.
# *   Kullanıcı inputlarını ve yaptığımız hesapları, raporlamak/loglamak amacıyla kaydetmek.
#
# **Programdan Beklenen Çıktılar**
# * Program kullanıcıya temelde 2 farklı işlem yapma imkanı sağlar.
# > 1. Menüyü görüntüleme
# > 3. Satın alma
# * Satın alınan her içecek tarih, fiyat bilgisi ile kaydedilmeli ve her zaman ulaşılabilir olmalıdır.

# %%
# 2.Problemin Çözümünü Buraya Yazınız
import datetime
menu = {"elma": 5, "muz": 10, "cilek": 10, "kivi": 7, "kavun": 5, "karpuz": 5, "seftali": 6}
def menuBak():
    print("=====MENU======")
    for i in list(menu.keys()):
        print(f"{i.upper()} : {menu[i]} TL")
    print("===============")

def fiyatHesap(urun, adet):
    if urun in list(menu.keys()) and adet > 0:
        return menu[urun] * int(adet)
    else:
        return None
def satinAlma():
    x = int(input("Menüyü görmek için 1'e, görmeden devam etmek için 2'ye basın"))
    if x == 1:
        menuBak()
    urunSayisi = int(input("Kaç tane ürün girmek istiyorsunuz?"))
    count = 1
    toplamFiyat = 0
    for i in range(urunSayisi):
        urun = input(f"{count}. Ürünü giriniz: ")
        if urun not in list(menu.keys()):
            a = int(input("Yazdığınız ürün menümüzde yok. Dilerseniz 1'e basarak yeniden girebilir veya 2'ye basarak bir sonraki ürüne geçebilirsiniz: "))
            if a == 1:
                urunSayisi += 1
                continue
            elif a == 2:
                count +=1
                continue 
            else: 
                a = int(input("Lütfen 1 ve 2 değerlerinden birini giriniz"))
        count += 1
        adet = int(input(f"{urun} ürününden kaç tane alıcaksınız?"))
        fiyat = fiyatHesap(urun,adet)
        toplamFiyat += fiyat
        with open("kasa.txt" , "a", encoding="utf-8") as f:
            f.write(f"{adet} tane {urun} = {fiyat} TL\n")
    simdi = datetime.datetime.now()
    tarih = simdi.date()
    saat = simdi.strftime("%H")
    dakika = simdi.strftime("%M")
    with open("kasa.txt", "a", encoding="utf-8") as f:
        f.write(f"Toplam fiyat = {toplamFiyat} TL\n")
        f.write(f"İşlem tarihi = {tarih}\n")
        f.write(f"İşlem saati = {saat} : {dakika}\n")
        f.write("--------------\n")
    with open("kasa.txt", "r", encoding="utf-8") as f:
        kasa = f.read()
        print(kasa)
satinAlma()
# Out:
# 3 tane elma = 15 TL
# 3 tane muz = 30 TL
# Toplam fiyat = 45 TL
# İşlem tarihi = 2023-04-14
# İşlem saati = 14 : 50
# --------------
#
# 3 tane elma = 15 TL
# Toplam fiyat = 15 TL
# İşlem tarihi = 2023-04-14
# İşlem saati = 15 : 14
# --------------
